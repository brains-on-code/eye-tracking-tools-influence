# %% [markdown]
# #Ogama#

# %%
import pandas as pd
import os
import sqlite3
import numpy as np
import xml.etree.ElementTree as ET

import os

opt = dict()
# General variables for eye-tracking data
# maximum value of horizontal resolution in pixels
opt['xres'] = 1920.0
opt['yres'] = 1080.0  # maximum value of vertical resolution in pixels
# missing value for horizontal position in eye-tracking data (example data uses -xres). used throughout
# internal_helpers as signal for data loss
opt['missingx'] = -opt['xres']
# missing value for vertical position in eye-tracking data (example data uses -yres). used throughout
# internal_helpers as signal for data loss
opt['missingy'] = -opt['yres']
# sampling frequency of data (check that this value matches with values actually obtained from measurement!)
opt['freq'] = 250.0

# Variables for the calculation of visual angle
# These values are used to calculate noise measures (RMS and BCEA) of
# fixations. The may be left as is, but don't use the noise measures then.
# If either or both are empty, the noise measures are provided in pixels
# instead of degrees.
# screen size in cm
opt['scrSz'] = [55.0, 32.5]
# distance to screen in cm.
opt['disttoscreen'] = 65.0

# STEFFEN INTERPOLATION
# max duration (s) of missing values for interpolation to occur
opt['windowtimeInterp'] = 0.1
# amount of data (number of samples) at edges needed for interpolation
opt['edgeSampInterp'] = 2
# maximum displacement during missing for interpolation to be possible
opt['maxdisp'] = opt['xres'] * 0.2 * np.sqrt(2)

# # K-MEANS CLUSTERING
# time window (s) over which to calculate 2-means clustering (choose value so that max. 1 saccade can occur)
opt['windowtime'] = 0.2
# time window shift (s) for each iteration. Use zero for sample by sample processing
opt['steptime'] = 0.02
# maximum number of errors allowed in k-means clustering procedure before proceeding to next file
opt['maxerrors'] = 100
opt['downsamples'] = [2, 5, 10]
# use chebychev filter when down sampling? 1: yes, 0: no. requires signal processing toolbox. is what matlab's
# down sampling internal_helpers do, but could cause trouble (ringing) with the hard edges in eye-movement data
opt['downsampFilter'] = False

# # FIXATION DETERMINATION
# number of standard deviations above mean k-means weights will be used as fixation cutoff
opt['cutoffstd'] = 2.0
# number of MAD away from median fixation duration. Will be used to walk forward at fixation starts and backward at
# fixation ends to refine their placement and stop algorithm from eating into saccades
opt['onoffsetThresh'] = 3.0
# maximum Euclidean distance in pixels between fixations for merging
opt['maxMergeDist'] = 40.0
# maximum time in ms between fixations for merging
opt['maxMergeTime'] = 60.0
# minimum fixation duration after merging, fixations with shorter duration are removed from output
opt['minFixDur'] = 90.0
# Need to register numpy types to be able to save them in the database, as SQL only supports int8
sqlite3.register_adapter(np.int64, lambda val: int(val))
sqlite3.register_adapter(np.int32, lambda val: int(val))

# Path to database
database_path = 'G:\\Dokumente\\OgamaExperiments\\ExperimentEMIP\\Database\\Experiment4.db'


def add_to_sql(c, df_eyetracking, subject, task_name, starttime, endtime):
	

	# Add a table for the subject called Subject + 'RawData'
	c.execute("CREATE TABLE IF NOT EXISTS ["+ subject +"Rawdata] ([ID] integer PRIMARY KEY AUTOINCREMENT NOT NULL,[SubjectName] varchar(50) NOT NULL COLLATE NOCASE, [TrialSequence] integer NOT NULL, [Time] integer NOT NULL, [PupilDiaX] float, [PupilDiaY] float, [GazePosX] float, [GazePosY] float, [MousePosX] float, [MousePosY] float, [EventID] integer)")

	# Add data in the following scheme:
	# SubjectName = subject
	# TrialSequence = ' ImageName'
	# Time = ' StartTime'
	# GazePosX = ' X'
	# GazePosY = ' Y'

	# For each row in the dataframe
	for index, row in df_eyetracking.iterrows():
		# Insert the data into the table
		c.execute("INSERT INTO ["+ subject +"Rawdata] (SubjectName, TrialSequence, Time, GazePosX, GazePosY) VALUES (?, ?, ?, ?, ?)", (subject, task_name, row['time'], row['X'], row['Y']))


	c.execute("INSERT INTO Trials (SubjectName, TrialID, TrialName, TrialSequence, Category,  TrialStartTime, Duration) VALUES (?, ?, ?, ?, ?, ?, ?)", (subject, task_name, task_name, task_name, "",starttime, endtime))

def import_data_into_ogama(df_eyetracking, metadata):

	# normalize the time regarding eyetracking to 0
	df_eyetracking["time"] = df_eyetracking["time"].astype(float)
	df_eyetracking["time"] = df_eyetracking["time"] - df_eyetracking["time"].iloc[0]

	# drop unused columns
	df_eyetracking = df_eyetracking.drop(columns=["l_gaze_point_in_user_coordinate_system_x",
												"l_gaze_point_in_user_coordinate_system_y",
												"l_gaze_point_in_user_coordinate_system_z",
												"r_gaze_point_in_user_coordinate_system_x",
												"r_gaze_point_in_user_coordinate_system_y",
												"r_gaze_point_in_user_coordinate_system_z",
												"l_gaze_origin_in_user_coordinate_system_x",
												"l_gaze_origin_in_user_coordinate_system_y",
												"l_gaze_origin_in_user_coordinate_system_z",
												"r_gaze_origin_in_user_coordinate_system_x",
												"r_gaze_origin_in_user_coordinate_system_y",
												"r_gaze_origin_in_user_coordinate_system_z"])

	# convert eyetracking data to display coordinates
	df_eyetracking["l_display_x"] = df_eyetracking["l_display_x"].astype(float) * opt["xres"]
	df_eyetracking["l_display_y"] = df_eyetracking["l_display_y"].astype(float) * opt["yres"]
	df_eyetracking["r_display_x"] = df_eyetracking["r_display_x"].astype(float) * opt["xres"]
	df_eyetracking["r_display_y"] = df_eyetracking["r_display_y"].astype(float) * opt["yres"]

	# convert miss column to right integer used by I2MC
	df_eyetracking["l_miss_x"] = df_eyetracking.apply(lambda row: row["l_display_x"] < -opt["xres"] or row["l_display_x"] > 2 * opt["xres"], axis=1)
	df_eyetracking["l_miss_y"] = df_eyetracking.apply(lambda row: row["l_display_y"] < -opt["yres"] or row["l_display_y"] > 2 * opt["yres"], axis=1)
	df_eyetracking["r_miss_x"] = df_eyetracking.apply(lambda row: row["r_display_x"] < -opt["xres"] or row["r_display_x"] > 2 * opt["xres"], axis=1)
	df_eyetracking["r_miss_y"] = df_eyetracking.apply(lambda row: row["r_display_y"] < -opt["yres"] or row["r_display_y"] > 2 * opt["yres"], axis=1)

	df_eyetracking["l_miss"] = df_eyetracking.apply(lambda row: row["l_miss_x"] or row["l_miss_y"] or not row["l_valid"] >= 1, axis=1)
	df_eyetracking["r_miss"] = df_eyetracking.apply(lambda row: row["r_miss_x"] or row["r_miss_y"] or not row["r_valid"] >= 1, axis=1)

	# Set a default value for missing data
	df_eyetracking.loc[df_eyetracking["l_miss"], "l_display_x"] = opt["missingx"]
	df_eyetracking.loc[df_eyetracking["l_miss"], "l_display_y"] = opt["missingy"]
	df_eyetracking.loc[df_eyetracking["r_miss"], "r_display_x"] = opt["missingx"]
	df_eyetracking.loc[df_eyetracking["r_miss"], "r_display_y"] = opt["missingy"]

	# drop unused columns
	df_eyetracking = df_eyetracking.drop(columns=["l_miss_x", "l_miss_y", "r_miss_x", "r_miss_y", "l_miss", "r_miss"])

	# rename columns to match I2MC format
	df_eyetracking.rename(columns={"l_display_x": "L_X",
								"l_display_y": "L_Y",
								"r_display_x": "R_X",
								"r_display_y": "R_Y",
								"l_valid" : "LValidity",
								"r_valid" : "RValidity"}, inplace=True)
	
	# Add new columns X and Y which are the average of L_X and R_X and L_Y and R_Y
	df_eyetracking["X"] = (df_eyetracking["L_X"] + df_eyetracking["R_X"]) / 2
	df_eyetracking["Y"] = (df_eyetracking["L_Y"] + df_eyetracking["R_Y"]) / 2
	
	# Transform time to ms
	df_eyetracking["time"] = df_eyetracking["time"].astype(float) * 1000.0

	# Connect to database
	conn = sqlite3.connect(database_path)
	c = conn.cursor()

	add_to_sql(c, df_eyetracking, metadata["Participant"], metadata["Algorithm"], metadata["StartTime"], metadata["EndTime"])
	

	# Add subject to the Subjects table
	c.execute("INSERT INTO Subjects (SubjectName) VALUES (?)", (metadata["Participant"],))

	# Save the database
	conn.commit()

def drop_all_subject_tables():
	# Connect to database
	import sqlite3
	conn = sqlite3.connect(database_path)
	c = conn.cursor()

	for i in range(1, 72):
		# Drop the table named S + str(i) + "RawData"
		c.execute("DROP TABLE IF EXISTS S" + str(i) + "Rawdata")

	# Delete entries from Trials
	c.execute("DELETE FROM Trials")

	# Delete entries from Subjects
	c.execute("DELETE FROM Subjects")

	# Save the database
	conn.commit()

drop_all_subject_tables()

base_path = os.path.join(os.getcwd(), 'data\\24\\dataEvaluation\\')
path = os.path.join(base_path,'data\\filteredData\\filtered_data.csv')
csv_file = os.path.join(os.getcwd(), path)
df_behavioral = pd.read_csv(csv_file)
for index, row in df_behavioral.iterrows():

		# read in eyetracking file
		eyetracking_file = row["Eyetracking"]
		# Exchange './' with the current working directory
		eyetracking_file = os.path.join(base_path, eyetracking_file[2:])
		df_eyetracking = pd.read_csv(eyetracking_file)
		import_data_into_ogama(df_eyetracking, row)
# Out:
# import_data_into_ogama data/emip_dataset/rawdata/1_rawdata.tsv S1
# prepare_tobii_data data/emip_dataset/rawdata/1_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/2_rawdata.tsv S2
# prepare_tobii_data data/emip_dataset/rawdata/2_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/3_rawdata.tsv S3
# prepare_tobii_data data/emip_dataset/rawdata/3_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/4_rawdata.tsv S4
# prepare_tobii_data data/emip_dataset/rawdata/4_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/5_rawdata.tsv S5
# prepare_tobii_data data/emip_dataset/rawdata/5_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/6_rawdata.tsv S6
# prepare_tobii_data data/emip_dataset/rawdata/6_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/7_rawdata.tsv S7
# prepare_tobii_data data/emip_dataset/rawdata/7_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/8_rawdata.tsv S8
# prepare_tobii_data data/emip_dataset/rawdata/8_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/9_rawdata.tsv S9
# prepare_tobii_data data/emip_dataset/rawdata/9_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/10_rawdata.tsv S10
# prepare_tobii_data data/emip_dataset/rawdata/10_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/11_rawdata.tsv S11
# prepare_tobii_data data/emip_dataset/rawdata/11_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/12_rawdata.tsv S12
# prepare_tobii_data data/emip_dataset/rawdata/12_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/13_rawdata.tsv S13
# prepare_tobii_data data/emip_dataset/rawdata/13_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/14_rawdata.tsv S14
# prepare_tobii_data data/emip_dataset/rawdata/14_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/15_rawdata.tsv S15
# prepare_tobii_data data/emip_dataset/rawdata/15_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/16_rawdata.tsv S16
# prepare_tobii_data data/emip_dataset/rawdata/16_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/17_rawdata.tsv S17
# prepare_tobii_data data/emip_dataset/rawdata/17_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/18_rawdata.tsv S18
# prepare_tobii_data data/emip_dataset/rawdata/18_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/19_rawdata.tsv S19
# prepare_tobii_data data/emip_dataset/rawdata/19_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/20_rawdata.tsv S20
# prepare_tobii_data data/emip_dataset/rawdata/20_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/21_rawdata.tsv S21
# prepare_tobii_data data/emip_dataset/rawdata/21_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/22_rawdata.tsv S22
# prepare_tobii_data data/emip_dataset/rawdata/22_rawdata.tsv
# df_msg is empty mupliple_choice_rectangle.jpg
# df_msg is empty mupliple_choice_vehicle.jpg
# import_data_into_ogama data/emip_dataset/rawdata/23_rawdata.tsv S23
# prepare_tobii_data data/emip_dataset/rawdata/23_rawdata.tsv
# df_msg is empty mupliple_choice_rectangle.jpg
# import_data_into_ogama data/emip_dataset/rawdata/24_rawdata.tsv S24
# prepare_tobii_data data/emip_dataset/rawdata/24_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/25_rawdata.tsv S25
# prepare_tobii_data data/emip_dataset/rawdata/25_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/26_rawdata.tsv S26
# prepare_tobii_data data/emip_dataset/rawdata/26_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/27_rawdata.tsv S27
# prepare_tobii_data data/emip_dataset/rawdata/27_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/28_rawdata.tsv S28
# prepare_tobii_data data/emip_dataset/rawdata/28_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/29_rawdata.tsv S29
# prepare_tobii_data data/emip_dataset/rawdata/29_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/30_rawdata.tsv S30
# prepare_tobii_data data/emip_dataset/rawdata/30_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/31_rawdata.tsv S31
# prepare_tobii_data data/emip_dataset/rawdata/31_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/32_rawdata.tsv S32
# prepare_tobii_data data/emip_dataset/rawdata/32_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/33_rawdata.tsv S33
# prepare_tobii_data data/emip_dataset/rawdata/33_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/34_rawdata.tsv S34
# prepare_tobii_data data/emip_dataset/rawdata/34_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/35_rawdata.tsv S35
# prepare_tobii_data data/emip_dataset/rawdata/35_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/36_rawdata.tsv S36
# prepare_tobii_data data/emip_dataset/rawdata/36_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/37_rawdata.tsv S37
# prepare_tobii_data data/emip_dataset/rawdata/37_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/38_rawdata.tsv S38
# prepare_tobii_data data/emip_dataset/rawdata/38_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/39_rawdata.tsv S39
# prepare_tobii_data data/emip_dataset/rawdata/39_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/40_rawdata.tsv S40
# prepare_tobii_data data/emip_dataset/rawdata/40_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/41_rawdata.tsv S41
# prepare_tobii_data data/emip_dataset/rawdata/41_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/42_rawdata.tsv S42
# prepare_tobii_data data/emip_dataset/rawdata/42_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/43_rawdata.tsv S43
# prepare_tobii_data data/emip_dataset/rawdata/43_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/44_rawdata.tsv S44
# prepare_tobii_data data/emip_dataset/rawdata/44_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/45_rawdata.tsv S45
# prepare_tobii_data data/emip_dataset/rawdata/45_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/46_rawdata.tsv S46
# prepare_tobii_data data/emip_dataset/rawdata/46_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/47_rawdata.tsv S47
# prepare_tobii_data data/emip_dataset/rawdata/47_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/48_rawdata.tsv S48
# prepare_tobii_data data/emip_dataset/rawdata/48_rawdata.tsv
# df_msg is empty mupliple_choice_rectangle.jpg
# import_data_into_ogama data/emip_dataset/rawdata/49_rawdata.tsv S49
# prepare_tobii_data data/emip_dataset/rawdata/49_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/50_rawdata.tsv S50
# prepare_tobii_data data/emip_dataset/rawdata/50_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/51_rawdata.tsv S51
# prepare_tobii_data data/emip_dataset/rawdata/51_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/52_rawdata.tsv S52
# prepare_tobii_data data/emip_dataset/rawdata/52_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/53_rawdata.tsv S53
# prepare_tobii_data data/emip_dataset/rawdata/53_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/54_rawdata.tsv S54
# prepare_tobii_data data/emip_dataset/rawdata/54_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/55_rawdata.tsv S55
# prepare_tobii_data data/emip_dataset/rawdata/55_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/56_rawdata.tsv S56
# prepare_tobii_data data/emip_dataset/rawdata/56_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/57_rawdata.tsv S57
# prepare_tobii_data data/emip_dataset/rawdata/57_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/58_rawdata.tsv S58
# prepare_tobii_data data/emip_dataset/rawdata/58_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/59_rawdata.tsv S59
# prepare_tobii_data data/emip_dataset/rawdata/59_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/60_rawdata.tsv S60
# prepare_tobii_data data/emip_dataset/rawdata/60_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/61_rawdata.tsv S61
# prepare_tobii_data data/emip_dataset/rawdata/61_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/62_rawdata.tsv S62
# prepare_tobii_data data/emip_dataset/rawdata/62_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/63_rawdata.tsv S63
# prepare_tobii_data data/emip_dataset/rawdata/63_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/64_rawdata.tsv S64
# prepare_tobii_data data/emip_dataset/rawdata/64_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/65_rawdata.tsv S65
# prepare_tobii_data data/emip_dataset/rawdata/65_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/66_rawdata.tsv S66
# prepare_tobii_data data/emip_dataset/rawdata/66_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/67_rawdata.tsv S67
# prepare_tobii_data data/emip_dataset/rawdata/67_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/68_rawdata.tsv S68
# prepare_tobii_data data/emip_dataset/rawdata/68_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/69_rawdata.tsv S69
# prepare_tobii_data data/emip_dataset/rawdata/69_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/70_rawdata.tsv S70
# prepare_tobii_data data/emip_dataset/rawdata/70_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/71_rawdata.tsv S71
# prepare_tobii_data data/emip_dataset/rawdata/71_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/72_rawdata.tsv S72
# prepare_tobii_data data/emip_dataset/rawdata/72_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/73_rawdata.tsv S73
# prepare_tobii_data data/emip_dataset/rawdata/73_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/74_rawdata.tsv S74
# prepare_tobii_data data/emip_dataset/rawdata/74_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/75_rawdata.tsv S75
# prepare_tobii_data data/emip_dataset/rawdata/75_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/76_rawdata.tsv S76
# prepare_tobii_data data/emip_dataset/rawdata/76_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/77_rawdata.tsv S77
# prepare_tobii_data data/emip_dataset/rawdata/77_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/78_rawdata.tsv S78
# prepare_tobii_data data/emip_dataset/rawdata/78_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/79_rawdata.tsv S79
# prepare_tobii_data data/emip_dataset/rawdata/79_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/80_rawdata.tsv S80
# prepare_tobii_data data/emip_dataset/rawdata/80_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/81_rawdata.tsv S81
# prepare_tobii_data data/emip_dataset/rawdata/81_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/82_rawdata.tsv S82
# prepare_tobii_data data/emip_dataset/rawdata/82_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/83_rawdata.tsv S83
# prepare_tobii_data data/emip_dataset/rawdata/83_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/84_rawdata.tsv S84
# prepare_tobii_data data/emip_dataset/rawdata/84_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/85_rawdata.tsv S85
# prepare_tobii_data data/emip_dataset/rawdata/85_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/86_rawdata.tsv S86
# prepare_tobii_data data/emip_dataset/rawdata/86_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/87_rawdata.tsv S87
# prepare_tobii_data data/emip_dataset/rawdata/87_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/88_rawdata.tsv S88
# prepare_tobii_data data/emip_dataset/rawdata/88_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/89_rawdata.tsv S89
# prepare_tobii_data data/emip_dataset/rawdata/89_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/90_rawdata.tsv S90
# prepare_tobii_data data/emip_dataset/rawdata/90_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/91_rawdata.tsv S91
# prepare_tobii_data data/emip_dataset/rawdata/91_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/92_rawdata.tsv S92
# prepare_tobii_data data/emip_dataset/rawdata/92_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/93_rawdata.tsv S93
# prepare_tobii_data data/emip_dataset/rawdata/93_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/94_rawdata.tsv S94
# prepare_tobii_data data/emip_dataset/rawdata/94_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/95_rawdata.tsv S95
# prepare_tobii_data data/emip_dataset/rawdata/95_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/96_rawdata.tsv S96
# prepare_tobii_data data/emip_dataset/rawdata/96_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/97_rawdata.tsv S97
# prepare_tobii_data data/emip_dataset/rawdata/97_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/98_rawdata.tsv S98
# prepare_tobii_data data/emip_dataset/rawdata/98_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/99_rawdata.tsv S99
# prepare_tobii_data data/emip_dataset/rawdata/99_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/100_rawdata.tsv S100
# prepare_tobii_data data/emip_dataset/rawdata/100_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/101_rawdata.tsv S101
# prepare_tobii_data data/emip_dataset/rawdata/101_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/102_rawdata.tsv S102
# prepare_tobii_data data/emip_dataset/rawdata/102_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/103_rawdata.tsv S103
# prepare_tobii_data data/emip_dataset/rawdata/103_rawdata.tsv
# df_msg is empty mupliple_choice_vehicle.jpg
# import_data_into_ogama data/emip_dataset/rawdata/104_rawdata.tsv S104
# prepare_tobii_data data/emip_dataset/rawdata/104_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/105_rawdata.tsv S105
# prepare_tobii_data data/emip_dataset/rawdata/105_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/106_rawdata.tsv S106
# prepare_tobii_data data/emip_dataset/rawdata/106_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/107_rawdata.tsv S107
# prepare_tobii_data data/emip_dataset/rawdata/107_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/108_rawdata.tsv S108
# prepare_tobii_data data/emip_dataset/rawdata/108_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/109_rawdata.tsv S109
# prepare_tobii_data data/emip_dataset/rawdata/109_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/110_rawdata.tsv S110
# prepare_tobii_data data/emip_dataset/rawdata/110_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/111_rawdata.tsv S111
# prepare_tobii_data data/emip_dataset/rawdata/111_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/112_rawdata.tsv S112
# prepare_tobii_data data/emip_dataset/rawdata/112_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/113_rawdata.tsv S113
# prepare_tobii_data data/emip_dataset/rawdata/113_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/114_rawdata.tsv S114
# prepare_tobii_data data/emip_dataset/rawdata/114_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/115_rawdata.tsv S115
# prepare_tobii_data data/emip_dataset/rawdata/115_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/116_rawdata.tsv S116
# prepare_tobii_data data/emip_dataset/rawdata/116_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/117_rawdata.tsv S117
# prepare_tobii_data data/emip_dataset/rawdata/117_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/118_rawdata.tsv S118
# prepare_tobii_data data/emip_dataset/rawdata/118_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/119_rawdata.tsv S119
# prepare_tobii_data data/emip_dataset/rawdata/119_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/120_rawdata.tsv S120
# prepare_tobii_data data/emip_dataset/rawdata/120_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/121_rawdata.tsv S121
# prepare_tobii_data data/emip_dataset/rawdata/121_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/122_rawdata.tsv S122
# prepare_tobii_data data/emip_dataset/rawdata/122_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/123_rawdata.tsv S123
# prepare_tobii_data data/emip_dataset/rawdata/123_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/124_rawdata.tsv S124
# prepare_tobii_data data/emip_dataset/rawdata/124_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/125_rawdata.tsv S125
# prepare_tobii_data data/emip_dataset/rawdata/125_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/126_rawdata.tsv S126
# prepare_tobii_data data/emip_dataset/rawdata/126_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/127_rawdata.tsv S127
# prepare_tobii_data data/emip_dataset/rawdata/127_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/128_rawdata.tsv S128
# prepare_tobii_data data/emip_dataset/rawdata/128_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/129_rawdata.tsv S129
# prepare_tobii_data data/emip_dataset/rawdata/129_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/130_rawdata.tsv S130
# prepare_tobii_data data/emip_dataset/rawdata/130_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/131_rawdata.tsv S131
# prepare_tobii_data data/emip_dataset/rawdata/131_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/132_rawdata.tsv S132
# prepare_tobii_data data/emip_dataset/rawdata/132_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/133_rawdata.tsv S133
# prepare_tobii_data data/emip_dataset/rawdata/133_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/134_rawdata.tsv S134
# prepare_tobii_data data/emip_dataset/rawdata/134_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/135_rawdata.tsv S135
# prepare_tobii_data data/emip_dataset/rawdata/135_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/136_rawdata.tsv S136
# prepare_tobii_data data/emip_dataset/rawdata/136_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/137_rawdata.tsv S137
# prepare_tobii_data data/emip_dataset/rawdata/137_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/138_rawdata.tsv S138
# prepare_tobii_data data/emip_dataset/rawdata/138_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/139_rawdata.tsv S139
# prepare_tobii_data data/emip_dataset/rawdata/139_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/140_rawdata.tsv S140
# prepare_tobii_data data/emip_dataset/rawdata/140_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/141_rawdata.tsv S141
# prepare_tobii_data data/emip_dataset/rawdata/141_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/142_rawdata.tsv S142
# prepare_tobii_data data/emip_dataset/rawdata/142_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/143_rawdata.tsv S143
# prepare_tobii_data data/emip_dataset/rawdata/143_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/144_rawdata.tsv S144
# prepare_tobii_data data/emip_dataset/rawdata/144_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/145_rawdata.tsv S145
# prepare_tobii_data data/emip_dataset/rawdata/145_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/146_rawdata.tsv S146
# prepare_tobii_data data/emip_dataset/rawdata/146_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/147_rawdata.tsv S147
# prepare_tobii_data data/emip_dataset/rawdata/147_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/148_rawdata.tsv S148
# prepare_tobii_data data/emip_dataset/rawdata/148_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/149_rawdata.tsv S149
# prepare_tobii_data data/emip_dataset/rawdata/149_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/150_rawdata.tsv S150
# prepare_tobii_data data/emip_dataset/rawdata/150_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/151_rawdata.tsv S151
# prepare_tobii_data data/emip_dataset/rawdata/151_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/152_rawdata.tsv S152
# prepare_tobii_data data/emip_dataset/rawdata/152_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/153_rawdata.tsv S153
# prepare_tobii_data data/emip_dataset/rawdata/153_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/154_rawdata.tsv S154
# prepare_tobii_data data/emip_dataset/rawdata/154_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/155_rawdata.tsv S155
# prepare_tobii_data data/emip_dataset/rawdata/155_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/156_rawdata.tsv S156
# prepare_tobii_data data/emip_dataset/rawdata/156_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/157_rawdata.tsv S157
# prepare_tobii_data data/emip_dataset/rawdata/157_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/158_rawdata.tsv S158
# prepare_tobii_data data/emip_dataset/rawdata/158_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/159_rawdata.tsv S159
# prepare_tobii_data data/emip_dataset/rawdata/159_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/160_rawdata.tsv S160
# prepare_tobii_data data/emip_dataset/rawdata/160_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/161_rawdata.tsv S161
# prepare_tobii_data data/emip_dataset/rawdata/161_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/162_rawdata.tsv S162
# prepare_tobii_data data/emip_dataset/rawdata/162_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/163_rawdata.tsv S163
# prepare_tobii_data data/emip_dataset/rawdata/163_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/164_rawdata.tsv S164
# prepare_tobii_data data/emip_dataset/rawdata/164_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/165_rawdata.tsv S165
# prepare_tobii_data data/emip_dataset/rawdata/165_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/166_rawdata.tsv S166
# prepare_tobii_data data/emip_dataset/rawdata/166_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/167_rawdata.tsv S167
# prepare_tobii_data data/emip_dataset/rawdata/167_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/168_rawdata.tsv S168
# prepare_tobii_data data/emip_dataset/rawdata/168_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/169_rawdata.tsv S169
# prepare_tobii_data data/emip_dataset/rawdata/169_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/170_rawdata.tsv S170
# prepare_tobii_data data/emip_dataset/rawdata/170_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/171_rawdata.tsv S171
# prepare_tobii_data data/emip_dataset/rawdata/171_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/172_rawdata.tsv S172
# prepare_tobii_data data/emip_dataset/rawdata/172_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/173_rawdata.tsv S173
# prepare_tobii_data data/emip_dataset/rawdata/173_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/174_rawdata.tsv S174
# prepare_tobii_data data/emip_dataset/rawdata/174_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/175_rawdata.tsv S175
# prepare_tobii_data data/emip_dataset/rawdata/175_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/176_rawdata.tsv S176
# prepare_tobii_data data/emip_dataset/rawdata/176_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/177_rawdata.tsv S177
# prepare_tobii_data data/emip_dataset/rawdata/177_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/178_rawdata.tsv S178
# prepare_tobii_data data/emip_dataset/rawdata/178_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/179_rawdata.tsv S179
# prepare_tobii_data data/emip_dataset/rawdata/179_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/180_rawdata.tsv S180
# prepare_tobii_data data/emip_dataset/rawdata/180_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/181_rawdata.tsv S181
# prepare_tobii_data data/emip_dataset/rawdata/181_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/182_rawdata.tsv S182
# prepare_tobii_data data/emip_dataset/rawdata/182_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/183_rawdata.tsv S183
# prepare_tobii_data data/emip_dataset/rawdata/183_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/184_rawdata.tsv S184
# prepare_tobii_data data/emip_dataset/rawdata/184_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/185_rawdata.tsv S185
# prepare_tobii_data data/emip_dataset/rawdata/185_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/186_rawdata.tsv S186
# prepare_tobii_data data/emip_dataset/rawdata/186_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/187_rawdata.tsv S187
# prepare_tobii_data data/emip_dataset/rawdata/187_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/188_rawdata.tsv S188
# prepare_tobii_data data/emip_dataset/rawdata/188_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/189_rawdata.tsv S189
# prepare_tobii_data data/emip_dataset/rawdata/189_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/190_rawdata.tsv S190
# prepare_tobii_data data/emip_dataset/rawdata/190_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/191_rawdata.tsv S191
# prepare_tobii_data data/emip_dataset/rawdata/191_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/192_rawdata.tsv S192
# prepare_tobii_data data/emip_dataset/rawdata/192_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/193_rawdata.tsv S193
# prepare_tobii_data data/emip_dataset/rawdata/193_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/194_rawdata.tsv S194
# prepare_tobii_data data/emip_dataset/rawdata/194_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/195_rawdata.tsv S195
# prepare_tobii_data data/emip_dataset/rawdata/195_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/196_rawdata.tsv S196
# prepare_tobii_data data/emip_dataset/rawdata/196_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/197_rawdata.tsv S197
# prepare_tobii_data data/emip_dataset/rawdata/197_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/198_rawdata.tsv S198
# prepare_tobii_data data/emip_dataset/rawdata/198_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/199_rawdata.tsv S199
# prepare_tobii_data data/emip_dataset/rawdata/199_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/200_rawdata.tsv S200
# prepare_tobii_data data/emip_dataset/rawdata/200_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/201_rawdata.tsv S201
# prepare_tobii_data data/emip_dataset/rawdata/201_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/202_rawdata.tsv S202
# prepare_tobii_data data/emip_dataset/rawdata/202_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/203_rawdata.tsv S203
# prepare_tobii_data data/emip_dataset/rawdata/203_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/204_rawdata.tsv S204
# prepare_tobii_data data/emip_dataset/rawdata/204_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/205_rawdata.tsv S205
# prepare_tobii_data data/emip_dataset/rawdata/205_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/206_rawdata.tsv S206
# prepare_tobii_data data/emip_dataset/rawdata/206_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/207_rawdata.tsv S207
# prepare_tobii_data data/emip_dataset/rawdata/207_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/208_rawdata.tsv S208
# prepare_tobii_data data/emip_dataset/rawdata/208_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/209_rawdata.tsv S209
# prepare_tobii_data data/emip_dataset/rawdata/209_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/210_rawdata.tsv S210
# prepare_tobii_data data/emip_dataset/rawdata/210_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/211_rawdata.tsv S211
# prepare_tobii_data data/emip_dataset/rawdata/211_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/212_rawdata.tsv S212
# prepare_tobii_data data/emip_dataset/rawdata/212_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/213_rawdata.tsv S213
# prepare_tobii_data data/emip_dataset/rawdata/213_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/214_rawdata.tsv S214
# prepare_tobii_data data/emip_dataset/rawdata/214_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/215_rawdata.tsv S215
# prepare_tobii_data data/emip_dataset/rawdata/215_rawdata.tsv
# import_data_into_ogama data/emip_dataset/rawdata/216_rawdata.tsv S216
# prepare_tobii_data data/emip_dataset/rawdata/216_rawdata.tsv
